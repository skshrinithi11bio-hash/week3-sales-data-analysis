# %% [markdown]
# <a href="https://colab.research.google.com/github/skshrinithi11bio-hash/week3-sales-data-analysis/blob/main/week3_sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load CSV from Colab environment
csv_path = "/content/drive/MyDrive/arena files/sales_data.csv"

df = pd.read_csv(csv_path)

# Handle missing values
df["Quantity"] = df["Quantity"].fillna(df["Quantity"].mean())
df["Price"] = df["Price"].fillna(df["Price"].mean())

# Calculate total sales
df["Total_Sales"] = df["Quantity"] * df["Price"]

# Metrics
total_revenue = df["Total_Sales"].sum()
average_sales = df["Total_Sales"].mean()
best_selling_product = df.groupby("Product")["Total_Sales"].sum().idxmax()

print("SALES ANALYSIS REPORT")
print("------------------------")
print(f"Total Revenue       : ₹{total_revenue:,.2f}")
print(f"Average Sales Value : ₹{average_sales:,.2f}")
print(f"Best Selling Product: {best_selling_product}")
# Out:
# SALES ANALYSIS REPORT
# ------------------------
# Total Revenue       : ₹12,365,048.00
# Average Sales Value : ₹123,650.48
# Best Selling Product: Laptop

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
